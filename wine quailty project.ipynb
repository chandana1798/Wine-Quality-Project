# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import xgboost as xgb

# %%
pip install xgboost
# Out:
# ...
#
# ...

# %%
X=df.iloc[:,:-1]   # x is assigned with indep feat by iloc function
Y=df.iloc[:,-1]    # y is assigned with dep feat

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
Y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 0.575

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_pred,Y_test)
# Out:
# array([[  0,   0,   1,   0,   0,   0],
#        [  1,   0,   9,   6,   1,   0],
#        [  0,   5, 108,  42,   1,   1],
#        [  0,   7,  38,  92,  12,   1],
#        [  0,   1,   8,  26,  30,   3],
#        [  0,   0,   0,   3,   4,   0]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
# we are tuning three hyperparameters right now, we are passing the different values for both parameters
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,32,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'splitter' : ['best', 'random']

}
grid_search = GridSearchCV(estimator=clf,
                     param_grid=grid_param,
                     cv=5,
                    n_jobs =-1)
grid_search.fit(X_train,Y_train)
best_parameters = grid_search.best_params_
print(best_parameters)
# Out:
# {'criterion': 'entropy', 'max_depth': 25, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}

# %%
clf = DecisionTreeClassifier(criterion= 'entropy', max_depth= 25, min_samples_leaf= 1,min_samples_split= 3, splitter= 'random')
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=25, min_samples_split=3,
#                        splitter='random')

# %%
Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_pred,Y_test)
# Out:
# array([[  0,   1,   3,   0,   0,   0],
#        [  0,   0,  12,  10,   1,   0],
#        [  1,   6, 113,  52,   3,   1],
#        [  0,   6,  32,  89,  20,   1],
#        [  0,   0,   4,  18,  24,   2],
#        [  0,   0,   0,   0,   0,   1]], dtype=int64)

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.5675

# %%
import pickle
with open('model.pkl', 'wb') as f:
    pickle.dump(clf, f)

# %%
# %pwd
# Out:
# 'C:\\Users\\surya'
